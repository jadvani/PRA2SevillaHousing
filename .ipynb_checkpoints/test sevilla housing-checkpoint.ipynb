# %%
import pandas as pd

df = pd.read_excel (r'C:/Users/Javier/Downloads/Sevilla_housing.xlsx')

# %%
df.zipcode.unique()
# Out:
# array([41001, 41011, 41018, 41004, 41010, 41003, 41009, 41013, 41002,
#        41014, 41012, 41005, 41008, 41020, 41015, 41007, 41006, 41016,
#        41019], dtype=int64)

# %%
hotelsByZipCode = {
41001:48,
41011: 2,
41018: 5,
41004: 53,
41010: 5,
41003: 44,
41009: 2,
41013: 3,
41002: 17,
41014: 3,
41012: 3,
41005: 2,
41008: 1,
41020: 6,
41015: 0,
41007: 3,
41006: 1,
41016: 1,
41019: 0
}

# %%
hotelsByZipCode["41020"]
# Out:
# 6

# %%
df["hotels"] = df["zipcode"].map(hotelsByZipCode)

# %%
df.head(10)
# Out:
#                                               tittle  \
# 0                   Ático en Arenal - Museo, Sevilla
# 1                   Ático en Arenal - Museo, Sevilla
# 2         Ático en Asunción - Adolfo Suárez, Sevilla
# 3  Ático en avenida de Kansas City, Luis Montoto ...
# 4  Ático en calle Alfalfa, Santa Cruz - Alfalfa, ...
# 5  Ático en calle Alfarería, Calle Betis - Pagés ...
# 6  Ático en calle Álvarez Quintero, Sevilla, Sant...
# 7  Ático en calle Amador de los Ríos, 26, Puerta ...
# 8  Ático en calle Doctor Jerónimo Pou, Ronda de T...
# 9  Ático en calle Don Fadrique, Parlamento - Torn...
#
#                                               url   rooms price  meters  \
# 0   /inmueble/85835126/?xtmc=1_1_Sevilla&xtcr=330  4 hab.   750  165 m²
# 1   /inmueble/88180305/?xtmc=1_1_Sevilla&xtcr=180  1 hab.   298   80 m²
# 2   /inmueble/81190853/?xtmc=1_1_Sevilla&xtcr=750  2 hab.   550  175 m²
# 3   /inmueble/88248622/?xtmc=1_1_Sevilla&xtcr=120  4 hab.   300  150 m²
# ...

# %%
df.to_excel(r'C:/Users/Javier/Downloads/Sevilla_housing_hotels.xlsx', index = False)
